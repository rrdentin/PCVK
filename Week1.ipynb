# %% [markdown]
# <a href="https://colab.research.google.com/github/rrdentin/PCVK/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Langkah (Step) 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# #Langkah (Step) 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)				                  #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)	#convert color to RGB
  final_frame = cv.hconcat((image, image_2))	    #concatenate image
  cv2_imshow(final_frame)				                  #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# #Langkah (Step) 3
# melihat ukuran File image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# #Langkah (Step) 4
# mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# #**Pertanyaan**
#
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
#
#   **Jawab:** Karena Google Colab memungkinkan penggunanya untuk menulis dan mengeksekusi Python di browser tanpa memerlukan konfigurasi, dapat mengakses GPU secara gratis, serta dapat berbagi kode program (kolaborasi tim) dengan mudah. Google Colab dapat mengeksekusi, menulis, menyimpan bahkan membagikan kode program yang telah dibuat melalui google drive. Penulisan kode program Python serta eksekusi kode program tersebut tidak memerlukan proses instalasi dengan mendownload installer pada komputer. Instalasi tidak perlu dilakukan karena semua proses dilakukan di cloud. Selain itu fungsionalitas tambahan Python dapat juga memanfaatkan built-in library yang ada pada Google Colab.
#
# 2.	Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
#   **Jawab:** Ya, semua library harus digunakan dalam praktikum sesi ini agar dapat menampilkan output yang diinginkan
#
#
#   *   [Numpy](https://numpy.org/doc/stable/) adalah library Python yang fokus pada scientific computing. NumPy memiliki kemampuan untuk membentuk objek N-dimensional array, yang mirip dengan list pada Python.
#   *   [Pandas](https://pandas.pydata.org/docs/) adalah library Python yang fokus untuk proses analisis data seperti manipulasi data, persiapan data, dan pembersihan data.
#   *   [CV2](https://docs.opencv.org/4.x/d1/dfb/intro.html) adalah open source library yang sangat berguna untuk computer vision applications seperti video analysis, CCTV footage analysis dan image analysis.
#   *   [Skimage](https://scikit-image.org/docs/stable/user_guide/getting_started.html) adalah image processing Python package yang bekerja dengan numpy arrays.
#   *   [PIL](https://pypi.org/project/Pillow/) adalah library open-source tambahan untuk Python yang fungsi utamanya adalah memanipulasi file gambar.
#   *   [Matplotlib](https://matplotlib.org/)  adalah library Python yang fokus pada visualisasi data seperti membuat plot grafik.
#
#
#
# 3.	Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ![Screenshot 2023-08-29 142803.png](data:image/png;base64,...)
#
#   Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
#
#     **Jawab:** Kegunaan kode program tersebut adalah untuk mengubah ukuran gambar dengan menggunakan kedua sumbu (Vertical dan Horizontal) sehingga gambar yang dihasilkan menjadi lebih kecil dari gambar asli. Faktor skala fx dan fy dalam kode tersebut mengontrol seberapa besar pengurangan ukuran akan terjadi pada sumbu horizontal dan vertikal, masing-masing.
#
#     Pengaruhnya apabila tidak dilakukan gambar akan tetap memiliki ukuran aslinya dan tidak mengalami perubahan ukuran yang akan dapat berdampak pada konsumsi memori yang lebih tinggi jika gambar memiliki resolusi yang besar dan perlu ditampilkan di layar dengan ukuran yang lebih kecil, juga gambar mungkin tampak terlalu besar jika ditampilkan di area dengan ukuran terbatas. Oleh karena itu, penggunaan cv.resize() sering berguna untuk mengontrol tampilan dan penggunaan memori gambar sesuai dengan kebutuhan.
#
# 4.	Perhatikan potongan kode progam berikut:
#
#   ![Screenshot 2023-08-29 143857.png](data:image/png;base64,...)
#
#     Apakah kegunaan kode [255,255,255] ? Jelaskan!
#
#     **Jawab:** Nilai [255, 255, 255] adalah representasi warna dalam model warna RGB (Red-Green-Blue). Setiap elemen dalam nilai tersebut mewakili intensitas warna merah, hijau, dan biru dalam rentang 0 hingga 255. Ketika ketiga elemen memiliki nilai maksimal (255) seperti dalam [255, 255, 255], ini mewakili warna putih.
#
# 5.	Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
#   **Jawab:** Keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah adalah Semakin tinggi resolusi, semakin bagus kualitas gambar. Sebaliknya, semakin rendah resolusi, maka semakin rendah kualitas gambar. Resolusi adalah jumlah pixel atau picture element yang tersusun dalam sebuah gambar digital. Resolusi adalah kerapatan pixel pada sebuah gambar dan tersusun dari pixel (kotak kecil).

# %% [markdown]
# #Tugas
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)				                  #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size

  tinggi = image.shape[0]
  lebar = image.shape[1]
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


  #membuat garis vertical ditengah image
  for x in range(tinggi):
    image_3[x, int(lebar/2)] = [255, 255, 255]

  final_frame = cv.hconcat((image_2, image_3))
  cv2_imshow(final_frame)

   #membuat garis menyilang diagonal image
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
#membuat garis horizontal ditengah dengan panjang tertentu
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
#garis horizontal
for y in range (100,200):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (100,200):
  for x in range (100,200):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
